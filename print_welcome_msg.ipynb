# %% [markdown]
# Q4. Create a “/welcome” route to display the welcome message “Welcome to ABC Corporation” and a “/”
# route to show the following details:
# Company Name: ABC Corporation
# Location: India
# Contact Detail: 999-999-9999

# %% [markdown]
# flask code

# %% [markdown]
# ![https___blue-translator-artak.pwskills.app_5000 - Google Chrome 22-02-2023 17_47_01.png](attachment:f601fe2e-c240-43d9-bae6-48af8fb498d1.png)

# %% [markdown]
# output from "/welcome" route

# %% [markdown]
# ![https___blue-translator-artak.pwskills.app_5000 - Google Chrome 22-02-2023 17_46_28.png](attachment:950863ab-fdc8-41f2-bb4c-d27903a4e10e.png)

# %% [markdown]
# output from "/" route

# %% [markdown]
# ![https___blue-translator-artak.pwskills.app_5000 - Google Chrome 22-02-2023 17_46_47.png](attachment:4a1f90fc-8930-4211-86f7-1a90805a5abb.png)
