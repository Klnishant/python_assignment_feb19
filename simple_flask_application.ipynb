# %% [markdown]
# Q2. Create a simple Flask application to display ‘Hello World!!’. Attach the screenshot of the output in
# Jupyter Notebook.

# %% [markdown]
# ![flask_code.png.png](attachment:84d3d2e4-21b9-488b-91ad-ea9df6e5fa2d.png)

# %% [markdown]
# Output

# %% [markdown]
# ![client_output.png.png](attachment:d66c33e3-b780-4d6d-90e8-aa7a4a0b7740.png)
